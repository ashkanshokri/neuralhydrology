# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

from helpers import evaluate_experiments


import xarray as xr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_path = Path('/Users/sho108/Desktop/r/work/sho108/neuralhydrology_workflow/runs_mse')

# %%
# test
exps = [
    {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'},
    ]
df = evaluate_experiments(exps, base_path=base_path)
# Out:
# {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'}
# Loading results for each run.
# 100%|██████████| 6/6 [00:00<00:00, 32.00it/s]
# Combining results and calculating metrics.
# 100%|██████████| 111/111 [00:04<00:00, 25.92it/s]
# Loading results for each run.
# 100%|██████████| 6/6 [00:00<00:00, 52.60it/s]
# Combining results and calculating metrics.
# ...
# 100%|██████████| 222/222 [00:07<00:00, 28.40it/s]
#          52103942 function calls (51487594 primitive calls) in 20.188 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        38    1.022    0.027    1.170    0.031 pathlib.py:438(_select_from)
#    164831    0.867    0.000    0.868    0.000 {built-in method posix.stat}
#    164756    0.484    0.000    1.757    0.000 <frozen importlib._bootstrap_external>:1536(find_spec)
# 6048474/6046737    0.460    0.000    1.108    0.000 {built-in method builtins.isinstance}
# ...

# %%
# AWAP vs SILO precipitation only
exps = [
    {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_Prs__*', 'name': 'spatial_Prs', 'method': 'spatial'},    
    ]

_eval(exps)


exps = [
    {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_Prs__*', 'name': 'temporal_Prs', 'method': 'temporal'},    
    ]
_eval(exps)
# Out:
# {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'}
# ...
# 100%|██████████| 222/222 [00:04<00:00, 48.95it/s]
# {'pattern': 'spatial_twofold_{fold:d}_Prs__*', 'name': 'spatial_Prs', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 50.22it/s]
# {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.83it/s]
# {'pattern': 'temporal_twofold_{fold:d}_Prs__*', 'name': 'temporal_Prs', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.66it/s]
#           temporal_Pra  temporal_Prs
# 102101A       0.512375      0.510831
# 104001A       0.679540      0.730381
# 105101A       0.211256      0.235583
# 105102A       0.461859      0.493950
# 105105A       0.555898      0.469750
# ...                ...           ...
# G8200045      0.516141      0.533392
# G8210010      0.392724      0.422005
# G9030124      0.456491      0.478417
# ...

# %%
# Prcip AWAP and et_morton_point_SILO
exps = [
    {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_PraEts__*', 'name': 'temporal_PraEts', 'method': 'temporal'},
    ]
_eval(exps)


exps = [
    {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_PraEts__*', 'name': 'spatial_PraEts', 'method': 'spatial'},
    ]
_eval(exps)
# Out:
# {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.20it/s]
# {'pattern': 'temporal_twofold_{fold:d}_PraEts__*', 'name': 'temporal_PraEts', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:11<00:00, 20.12it/s]
# {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 49.32it/s]
# {'pattern': 'spatial_twofold_{fold:d}_PraEts__*', 'name': 'spatial_PraEts', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:05<00:00, 39.34it/s]
#           spatial_Pra  spatial_PraEts
# 104001A      0.717495        0.673156
# 107001B      0.552889        0.702272
# 108003A      0.616242        0.558799
# 112002A      0.770015        0.771397
# 112102A      0.742661        0.774355
# ...               ...             ...
# G8140040     0.142147             NaN
# G8190001     0.599327             NaN
# G8200045     0.547164             NaN
# ...

# %%
# Prcip SILO and et_morton_point_SILO | et_morton_actual_SILO
exps = [
    {'pattern': 'temporal_twofold_{fold:d}_Prs__*', 'name': 'temporal_Pra', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_PrsEts__*', 'name': 'temporal_PraEts', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_PrsEas__*', 'name': 'temporal_PraEas', 'method': 'temporal'},
    ]
_eval(exps)


exps = [
    {'pattern': 'spatial_twofold_{fold:d}_Prs__*', 'name': 'spatial_Pra', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_PrsEts__*', 'name': 'spatial_PraEts', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_PrsEas__*', 'name': 'spatial_PraEas', 'method': 'spatial'},
    ]
_eval(exps)
# Out:
# {'pattern': 'temporal_twofold_{fold:d}_Prs__*', 'name': 'temporal_Pra', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:11<00:00, 20.07it/s]
# {'pattern': 'temporal_twofold_{fold:d}_PrsEts__*', 'name': 'temporal_PraEts', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.74it/s]
# {'pattern': 'temporal_twofold_{fold:d}_PrsEas__*', 'name': 'temporal_PraEas', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:11<00:00, 20.17it/s]
# {'pattern': 'spatial_twofold_{fold:d}_Prs__*', 'name': 'spatial_Pra', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 51.96it/s]
# {'pattern': 'spatial_twofold_{fold:d}_PrsEts__*', 'name': 'spatial_PraEts', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 51.60it/s]
# {'pattern': 'spatial_twofold_{fold:d}_PrsEas__*', 'name': 'spatial_PraEas', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 51.81it/s]
#           spatial_Pra  spatial_PraEts  spatial_PraEas
# ...

# %%
# compare dynamic features
dynamic_predictors = ['Pra',
              'PraEts',
              'Prs',
              'PrsEts',
              'PrsEas',
              ]

exps = [
    {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_PraEts__*', 'name': 'spatial_PraEts', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_Prs__*', 'name': 'spatial_Prs', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_PrsEts__*', 'name': 'spatial_PrsEts', 'method': 'spatial'},
    {'pattern': 'spatial_twofold_{fold:d}_PrsEas__*', 'name': 'spatial_PrsEas', 'method': 'spatial'},
    ]

spatial_df_dynamic_feat = _eval(exps)
# Out:
# {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 53.31it/s]
# {'pattern': 'spatial_twofold_{fold:d}_PraEts__*', 'name': 'spatial_PraEts', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:05<00:00, 39.90it/s]
# {'pattern': 'spatial_twofold_{fold:d}_Prs__*', 'name': 'spatial_Prs', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 49.64it/s]
# {'pattern': 'spatial_twofold_{fold:d}_PrsEts__*', 'name': 'spatial_PrsEts', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 49.26it/s]
# {'pattern': 'spatial_twofold_{fold:d}_PrsEas__*', 'name': 'spatial_PrsEas', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 48.95it/s]

# %%
# compare dynamic features


exps = [
    {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_PraEts__*', 'name': 'temporal_PraEts', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_Prs__*', 'name': 'temporal_Prs', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_PrsEts__*', 'name': 'temporal_PrsEts', 'method': 'temporal'},
    {'pattern': 'temporal_twofold_{fold:d}_PrsEas__*', 'name': 'temporal_PrsEas', 'method': 'temporal'},
    ]

temporal_df_dynamic_feat = _eval(exps)
# Out:
# {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:11<00:00, 19.68it/s]
# {'pattern': 'temporal_twofold_{fold:d}_PraEts__*', 'name': 'temporal_PraEts', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.50it/s]
# {'pattern': 'temporal_twofold_{fold:d}_Prs__*', 'name': 'temporal_Prs', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.52it/s]
# {'pattern': 'temporal_twofold_{fold:d}_PrsEts__*', 'name': 'temporal_PrsEts', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.40it/s]
# {'pattern': 'temporal_twofold_{fold:d}_PrsEas__*', 'name': 'temporal_PrsEas', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.57it/s]

# %%
# compare static_features
static_attributes = [
    '',
    'Are',  # Catchment Area
    'Pme',  # Precipitation Mean #THIS
    'Pet',  # PET Mean #THIS
    'Run',  # Runoff Ratio
    'Slo',  # Slope FDC
    'Str',  # Stream Elasticity
    'Bas',  # Baseflow Index #THIS
    'Hpf',  # High Precipitation Frequency
    'Hpd',  # High Precipitation Duration #THIS
    'Lpf',  # Low Precipitation Frequency
    'Lpd',  # Low Precipitation Duration #THIS
    'Mea',  # Mean Slope Percentage
    'Ksa',  # Saturation Hydraulic Conductivity (Ksat)
    'Ari',  # Aridity Index
    'Pse',  # Precipitation Seasonality Index
    'PmePetBasHpdLpdKsa',
]

static_attributes = [
    '',
    'PmePetBasHpdLpdKsa',
]


exps = [
    {
        'pattern': '%s_twofold_{fold:d}_PraEts_%s_*' % (method, static_feat),
        'name': '%s_%s' % (method, static_feat),
        'method': method
    }
    for method in ['spatial'] #, 'temporal'
    for static_feat in static_attributes
]

mem = 'max'
df_dict = dict()
for exp in exps:
    print(exp) 
    ens_list = all_folds(exp['pattern'], base_path)
    combined_ensemble = join(ens_list, exp['method'])
    df = get_ensemble_metric(combined_ensemble, target_var='streamflow_mmd', metric='NSE', freq='1D')
    name = exp['name'] or exp['pattern']
    
    if isinstance(mem, str):
        if mem == 'max':
            df_dict[name] = df.iloc[:,df.median().argmax()]
        else:
            # notimplemente error
            raise
    else:
        df_dict[name] = df.iloc[:,mem]

all_metrics = pd.DataFrame.from_dict(df_dict)

_, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,7))
_boxplot(all_metrics, ax=ax1)
_fdc(all_metrics, ax=ax2)
# Out:
# {'pattern': 'spatial_twofold_{fold:d}_PraEts__*', 'name': 'spatial_', 'method': 'spatial'}
# ...
# 100%|██████████| 222/222 [00:05<00:00, 39.49it/s]
# {'pattern': 'spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_PmePetBasHpdLpdKsa', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:02<00:00, 104.39it/s]

# %%
exps = [
    {'pattern': 'seq_length_5_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_5', 'method': 'spatial'},
    {'pattern': 'seq_length_10_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_10', 'method': 'spatial'},
    {'pattern': 'seq_length_20_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_20', 'method': 'spatial'},
    {'pattern': 'seq_length_50_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_50', 'method': 'spatial'},
    {'pattern': 'seq_length_365_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_365', 'method': 'spatial'},
    {'pattern': 'seq_length_730_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_730', 'method': 'spatial'},
    ]


temporal_df_dynamic_feat = _eval(exps)
# Out:
# {'pattern': 'seq_length_5_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_5', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:03<00:00, 62.80it/s]
# {'pattern': 'seq_length_10_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_10', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:03<00:00, 60.79it/s]
# {'pattern': 'seq_length_20_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_20', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:03<00:00, 60.91it/s]
# {'pattern': 'seq_length_50_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_50', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 52.69it/s]
# {'pattern': 'seq_length_365_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_365', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 51.74it/s]
# ...

# %%
exps = [
    {'pattern': 'seq_length_5_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_5', 'method': 'temporal'},
    {'pattern': 'seq_length_10_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_10', 'method': 'temporal'},
    {'pattern': 'seq_length_20_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_20', 'method': 'temporal'},
    {'pattern': 'seq_length_50_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_50', 'method': 'temporal'},
    {'pattern': 'seq_length_365_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_365', 'method': 'temporal'},
    {'pattern': 'seq_length_730_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_730', 'method': 'temporal'},
    ]

temporal_df_dynamic_feat = _eval(exps)
# Out:
# {'pattern': 'seq_length_5_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_5', 'method': 'temporal'}
# Loading results for each run.
# 100%|██████████| 5/5 [00:59<00:00, 11.86s/it]
# Combining results and calculating metrics.
#  82%|████████▏ | 183/222 [01:44<00:31,  1.23it/s]
# Basin 803003 All observed values are NaN, thus metrics will be NaN, too.
# Basin 803003 All observed values are NaN, thus metrics will be NaN, too.
# Basin 803003 All observed values are NaN, thus metrics will be NaN, too.
# Basin 803003 All observed values are NaN, thus metrics will be NaN, too.
# Basin 803003 All observed values are NaN, thus metrics will be NaN, too.
#  83%|████████▎ | 184/222 [01:46<00:47,  1.25s/it]
# Basin 803003 All observed values are NaN, thus metrics will be NaN, too.
# 100%|██████████| 222/222 [02:03<00:00,  1.80it/s]
# Loading results for each run.
# 100%|██████████| 5/5 [01:03<00:00, 12.79s/it]
# Combining results and calculating metrics.
# ...

# %%
# Spatial vs temporal
exps = [
    {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'},
    {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'},
    ]

_eval(exps)
# Out:
# {'pattern': 'spatial_twofold_{fold:d}_Pra__*', 'name': 'spatial_Pra', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 51.66it/s]
# {'pattern': 'temporal_twofold_{fold:d}_Pra__*', 'name': 'temporal_Pra', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:10<00:00, 20.99it/s]
#           spatial_Pra  temporal_Pra
# 102101A      0.540975      0.512375
# 104001A      0.717495      0.679540
# 105101A     -0.028112      0.211256
# 105102A      0.533972      0.461859
# 105105A      0.496172      0.555898
# ...               ...           ...
# G8200045     0.547164      0.516141
# G8210010     0.420528      0.392724
# G9030124     0.340674      0.456491
# G9030250    -0.789830     -0.402623
# G9070142     0.563231      0.551379
#
# [222 rows x 2 columns]

# %%
# Spatial vs temporal
exps = [
    {'pattern': 'seq_length_5_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_5', 'method': 'temporal'},
    {'pattern': 'seq_length_5_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_5', 'method': 'spatial'},
    ]

df5 = _eval(exps)




# Spatial vs temporal
exps = [
    {'pattern': 'seq_length_365_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_365', 'method': 'temporal'},
    {'pattern': 'seq_length_365_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_365', 'method': 'spatial'},
    ]

df365 = _eval(exps)
# Out:
# {'pattern': 'seq_length_5_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_5', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:09<00:00, 24.21it/s]
# {'pattern': 'seq_length_5_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_5', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:03<00:00, 63.10it/s]
# {'pattern': 'seq_length_365_temporal_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'temporal_seqlen_365', 'method': 'temporal'}
# 100%|██████████| 222/222 [00:08<00:00, 25.10it/s]
# {'pattern': 'seq_length_365_spatial_twofold_{fold:d}_PraEts_PmePetBasHpdLpdKsa_*', 'name': 'spatial_seqlen_365', 'method': 'spatial'}
# 100%|██████████| 222/222 [00:04<00:00, 51.40it/s]

# %%
df365
# Out:
#           temporal_seqlen_365  spatial_seqlen_365
# 102101A              0.617178            0.573442
# 104001A              0.712252            0.691074
# 105101A              0.495832            0.443478
# 105102A              0.421304            0.489637
# 105105A              0.705835            0.710585
# ...                       ...                 ...
# G8200045             0.555641            0.464448
# G8210010             0.431062            0.269274
# G9030124             0.416953            0.412894
# G9030250             0.577052            0.509826
# G9070142             0.514849            0.512003
#
# [222 rows x 2 columns]

# %%
#df5.diff(axis=1).iloc[:,1]
# Out:
#           spatial_seqlen_365
# 102101A            -0.043736
# 104001A            -0.021178
# 105101A            -0.052354
# 105102A             0.068333
# 105105A             0.004750
# ...                      ...
# G8200045           -0.091193
# G8210010           -0.161788
# G9030124           -0.004059
# G9030250           -0.067226
# G9070142           -0.002846
#
# [222 rows x 1 columns]

# %%
shpfile = Path('/Users/sho108/Desktop/z/Data/CAMELS_AUS/02_location_boundary_area/shp/CAMELS_AUS_Boundaries_adopted.shp')

df_diff_t_s = pd.DataFrame(df5.diff(axis=1).iloc[:,1])
df_diff_t_s.columns=['diff temporal - spatial']

results = df_diff_t_s

import geopandas as gpd
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt

bp = Path('/Users/sho108/Desktop/r/work/sho108/neuralhydrology_workflow')
output_directory = bp / 'basins/twofoldsplit'

aus_shpfile = Path('/Users/sho108/Desktop/z/Data/CAMELS_AUS/02_location_boundary_area/shp/bonus data/Australia_boundaries.shp')
shpfile = Path('/Users/sho108/Desktop/z/Data/CAMELS_AUS/02_location_boundary_area/shp/CAMELS_AUS_Boundaries_adopted.shp')


kwargs = dict()
gdf = gpd.read_file(shpfile)
aus_gdf = gpd.read_file(aus_shpfile)
gdf_merged = pd.merge(gdf, results, left_on='CatchID', right_index=True)

# Create 'outputs' folder if not available
output_folder = Path('outputs')
output_folder.mkdir(parents=True, exist_ok=True)

fig, ax = plt.subplots(figsize=(10, 5))
gdf_merged.plot(column='diff temporal - spatial', cmap='bwr_r', vmin=-1, vmax=1, edgecolor='k', linewidth=0.3, ax=ax, legend=True)
aus_gdf.plot(ax=ax, facecolor='none', edgecolor='k', linewidth=0.2)
plt.xlim([111.5, 154])
plt.ylim([-44, -10])
plt.gca().set_aspect('equal')

output_file = output_folder / 'aaa.jpg'
plt.savefig(output_file, dpi=450)

plt.xlim([140, 150])
plt.ylim([-39, -34])
plt.gca().set_aspect('equal')

# %%
b
# Out:
# <xarray.DataArray 'q_sim' (time: 12417, station: 221)>
# [2744157 values with dtype=float32]
# Coordinates:
#   * time        (time) datetime64[ns] 1981-01-02 1981-01-03 ... 2014-12-31
#   * station     (station) int32 1 2 3 4 5 6 7 8 ... 215 216 217 218 219 220 221
#     lead_time   int32 0
#     ens_member  int32 1
# Attributes:
#     standard_name:         q_sim
#     long_name:             simulated streamflow
#     units:                 m3/s
#     type:                  3.0
#     type_description:      averaged over the preceding interval
#     dat_type:              sim
#     dat_type_description:  simulated
#     location_type:         point

# %%
xr.open_dataset(list(base_path.glob('*'))[0],decode_times=False).time
# Out:
# <xarray.DataArray 'time' (time: 12417)>
# array([    1,     2,     3, ..., 12415, 12416, 12417], dtype=int32)
# Coordinates:
#   * time     (time) int32 1 2 3 4 5 6 7 ... 12412 12413 12414 12415 12416 12417
# Attributes:
#     standard_name:  time
#     long_name:      time
#     time_standard:  UTC
#     axis:           t
#     units:          days since 1981-01-01 09:00:00.0 +0000

# %%
ds_obs['q_obs'].isel(ens_member=0, lead_time=0).time
# Out:
# <xarray.DataArray 'time' (time: 23376)>
# array([    1,     2,     3, ..., 23374, 23375, 23376], dtype=int32)
# Coordinates:
#   * time        (time) int32 1 2 3 4 5 6 ... 23371 23372 23373 23374 23375 23376
#     lead_time   int32 0
#     ens_member  int32 1
# Attributes:
#     standard_name:  time
#     long_name:      time
#     time_standard:  UTC
#     axis:           t
#     units:          days since 31-Dec-1950 09:00:00

# %%
# Out:
# '31-Dec-1950'

# %%
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 23376, station: 221, lead_time: 1, ens_member: 1)
# Coordinates:
#   * time          (time) datetime64[ns] 1951-01-01 1951-01-02 ... 2014-12-31
#   * station       (station) int32 1 2 3 4 5 6 7 ... 215 216 217 218 219 220 221
#   * lead_time     (lead_time) int32 0
#   * ens_member    (ens_member) int32 1
# Data variables:
#     station_id    (station) int32 ...
#     station_name  (station) |S30 ...
#     lat           (station) float32 ...
#     lon           (station) float32 ...
#     area          (station) float32 ...
#     q_obs         (time, ens_member, station, lead_time) float32 ...
#     q_obs_qual    (time, ens_member, station, lead_time) float64 ...
# Attributes:
#     title:                   Streamflow data assembled from the CAMELS AUS da...
#     institution:             CSIRO Land & Water
#     source:                  CAMELS aus dataset described by Fowler et al. (2...
#     catchment:               CAMELS Aus
# ...
